# %%
#Import thư viện
import numpy as np
import pandas as pd

df = pd.read_csv(r"C:\Users\nhngh\Desktop\DA\Datasets\AmesHousing.csv")
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
#Có 3 cách để xác định số dòng số cột của dữ liệu
#Cách 1: gọi DataFrame
df
#Cách 2: dùng DataFrame.shape
#Đối với DataFrame.shape thì phần tử đầu tiên [0] chính là số dòng, phần tử thứ 2 là số cột [1]
so_dong = df.shape[0]
so_cot = df.shape[1]

#Cách 3: dùng DataFrame.info()
#Info chắc chắn phải dùng, info cho chúng ta biết thông tin tổng quan của bộ dữ liệu bao gồm:
#Số lượng dữ liệu non-null trong từng cột, giúp chúng ta biết chi tiết số lượng dữ liệu khuyết thiếu của từng cột
#Loại dữ liệu của cột đó(int,float,obj)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
#DataFrame.columns giúp chúng ta biết được đầy đủ tên của những cột dữ liệu(chiều dữ liệu)
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
#Xác định thuộc tính của các cột dữ liệu
df.dtypes
# Out:
# Order               int64
# PID                 int64
# MS SubClass         int64
# MS Zoning          object
# Lot Frontage      float64
#                    ...
# Mo Sold             int64
# Yr Sold             int64
# Sale Type          object
# Sale Condition     object
# SalePrice           int64
# Length: 82, dtype: object

# %%
#DataFrame.rename đổi tên cột thuộc tính
#Syntax: columns = {"Tên cột cũ":"Tên cột mới","Tên Cột cũ":"Tên Cột mới",.......,}
#inplace = True(mà có trùng hay không trùng cũng sẽ sửa đổi trên dữ liệu gốc
#Nếu inplace = False thì không trùng mới chỉnh sửa trên dữ liệu gốc, còn nếu trùng sẽ tạo ra một DataFrame tạm
df.rename(columns={'Street':'Tên Đường', "Order":"Thứ Tự"},inplace=True)

# %%
#Thêm một cột mới
#Feature engineering
#Nếu như nằm trong ngoặc [] là một cột không tồn tại trong dataframe, thì DataFrame sẽ tự động tạo ra một cột mới
df["LotFrontArea"] = df["Lot Frontage"] * df["Lot Area"] 
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
#Thêm một cột mới bằng insert, tham số đầu tiên là index của cột sẽ chèn vào 
#Tham số thứ 2 sẽ là tên của cột mới
#Tham số thứ 3 sẽ là giá trị
#Nếu tên cột đã tồn tại, sẽ báo lại already exists.
df.insert(83,"TEST",pd.Series(5, index=df.index))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14912\1270486075.py in <module>
#       1 #
# ----> 2 df.insert(83,"TEST",pd.Series(5, index=df.index))
#       3 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4441         if not allow_duplicates and column in self.columns:
#    4442             # Should this be a different kind of error??
# -> 4443             raise ValueError(f"cannot insert {column}, already exists")
#    4444         if not isinstance(loc, int):
#    4445             raise TypeError("loc must be int")
#
# ValueError: cannot insert TEST, already exists

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
lst = [("Kế Toán", 20, 5), ("Giam Doc", 50), ("Nhan Vien",10)]
df1 = pd.DataFrame(lst)
df1
# Out:
#            0   1    2
# 0    Kế Toán  20  5.0
# 1   Giam Doc  50  NaN
# 2  Nhan Vien  10  NaN

# %%
lst = [("Kế Toán", 20, 5), ("Giam Doc", 50), ("Nhan Vien",10)]
df1 = pd.DataFrame(lst)
#df = df.append({‘Cột1':‘Giá trị1',‘Cột2':‘Giá trị2‘,…,’Cộtn':'Giá trị'}, ignore_index = True)
df1 = df.append({0:'Bao Ve',1:10, 2:4}, ignore_index = True)
# Out:
# C:\Users\nhngh\AppData\Local\Temp\ipykernel_14912\3553522418.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df.append({0:'Bao Ve',1:10, 2:4}, ignore_index = True)
